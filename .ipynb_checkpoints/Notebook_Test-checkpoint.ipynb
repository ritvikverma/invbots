# %%
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None  # default='warn'
input_path = 'item_value_table_input_sheet_20190704_on_20190710'
table_table_location_path = 'table_table_input_sheet_20190704_on_20190710'
calculation_header = ['table_id', 'from_value_row_index', 'from_value_column_index', 'to_value_row_index',
                      'to_value_column_index', 'weight']
calculation_list = []

def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

def str_to_float(s):
    return (float(s))


def bracket_to_negative(s):
    s = str(s)
    if (hasNumbers(s)):
        if '(' in s:
            s = s.replace('(', '')
            s = s.replace(')', '')
            s = '-' + s
    else:
        s = '0'
    return s

def clean_bs(df):    
    df['value_content'] = df['value_content'].str.strip()
    df['value_content'] = df['value_content'].str.replace('\t', '')
    df['value_content'] = df['value_content'].str.replace(',', '')
    df['value_content'] = df['value_content'].str.replace('HK$', '')
    # Billy: I am thinking if we should fillna
    df['value_content'] = df['value_content'].fillna(0)
    df['value_content'] = df['value_content'].apply(bracket_to_negative)
    df['value_content'] = df['value_content'].apply(str_to_float)
    return df

def create_calculation_table(child_row_index_list, table_id, parent_row_index, parent_col_index, weight):
    for k in child_row_index_list:
        calculation_list.append(
            [table_id, parent_row_index, parent_col_index, k, parent_col_index, weight])

def operate_sum_bs(df, col_index, table_id):
    # to hard code the table_id for development
    for index, row in df.iterrows():
        value_total = row['value_content']
        parent_row_index = row['value_row_index']
        parent_col_index = col_index
        # to skip the "value_content" = 0,
        if value_total != 0:
            j = parent_row_index - 1
            sum_sub_total = 0
            child_row_index_list = []
            # j != -1 -> to prevent the error when "value_column_index" = 0
            while j != -1 and value_total != sum_sub_total:
                # name_sub_total = row['item_name']
                if (whole_df.loc[((whole_df['value_row_index'] == j) & (whole_df['value_column_index'] == parent_col_index)), 'as_child'] == 0).values[0]:
                    sum_sub_total += df.loc[df['value_row_index'] == j, 'value_content'].values[0]
                    child_row_index_list.append(j)
                j -= 1
            if value_total == sum_sub_total:
                parent_label_condition = ((whole_df['value_row_index'] == parent_row_index) & (whole_df['value_column_index'] == parent_col_index))
                whole_df.loc[parent_label_condition, 'as_parent'] = parent_row_index
                for child_row_index in child_row_index_list:
                    child_label_condition = ((whole_df['value_row_index'] == child_row_index) & (whole_df['value_column_index'] == parent_col_index))
                    whole_df.loc[child_label_condition, 'as_child'] = parent_row_index
                create_calculation_table(child_row_index_list, table_id, parent_row_index, parent_col_index, 1)

def operate_minus_bs(df, col_index, table_id):  # A — B = C
    df_parents = df.loc[df['as_child'] == 0].loc[df['as_parent'] == 0].loc[
        df['value_content'] != 0]  # sets all the eligible parents for subtraction (C)
    for index_parent, parent in df_parents.iterrows():
        b_index = index_parent - 1  # selects first child (-B)
        found = False
        while found == False and b_index >= df.index[0]:
            if (df.loc[b_index, 'value_content'] == 0):
                b_index -= 1
                continue
            else:
                a_index = b_index - 1  # selects first sub-child for (A)
                while (found == False and a_index > df.index[0]):
                    if (df.loc[a_index, 'value_content'] == 0):
                        a_index -= 1
                        continue
                    else:
                        a = df.loc[a_index, 'value_content']
                        b = df.loc[b_index, 'value_content']
                        p = df.loc[index_parent, 'value_content']
                        if (a - b == p):
                            found = True
                            df.loc[index_parent, 'as_parent'] = (index_parent)  # sets parents and children
                            df.loc[a_index, 'as_child'] = (index_parent)
                            df.loc[b_index, 'as_child'] = (index_parent)
                            calculation_list.append(
                                [table_id, df.loc[index_parent, 'value_row_index'],
                                 df.loc[index_parent, 'value_column_index'],
                                 df.loc[a_index, 'value_row_index'], df.loc[a_index, 'value_column_index'], -1])
                            calculation_list.append(
                                [table_id, df.loc[index_parent, 'value_row_index'],
                                 df.loc[index_parent, 'value_column_index'],
                                 df.loc[b_index, 'value_row_index'], df.loc[b_index, 'value_column_index'], -1])
                        a_index -= 1
                b_index -= 1
    return df

# %%
input_path += '.csv'
table_table_location_path += '.csv'
calculation_df = pd.DataFrame(columns=calculation_header)
table_df = pd.read_csv(table_table_location_path)
main_df = pd.read_csv(input_path)
# table_names = ['bs', 'cfs', 'cfs_note']
table_names = ['bs']

# %%
whole_df = main_df.loc[main_df['table_id'] == 1413]

# %%
whole_df.loc[:, 'as_parent'] = 0
whole_df.loc[:, 'as_child'] = 0

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-3c96158d7549> in <module>
# ----> 1 clean_bs(whole_df)
#
# <ipython-input-53-a968e52feebe> in clean_bs(df)
#      35     df['value_content'] = df['value_content'].fillna(0)
#      36     df['value_content'] = df['value_content'].apply(bracket_to_negative)
# ---> 37     df['value_content'] = df['value_content'].apply(str_to_float)
#      38     return df
#      39
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-53-a968e52feebe> in str_to_float(s)
#      13
#      14 def str_to_float(s):
# ---> 15     return (float(s))
#      16
#      17
#
# ValueError: could not convert string to float: 'HK$83.06'
